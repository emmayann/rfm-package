# %%
from pathlib import Path
import pandas as pd

# %%
from rfmanalysis1 import RFMVisualizer,  RFMAnalysis

# %%
path = Path("diagnosys\\orders.csv")

# %%
data = pd.read_csv(path)

# %%
rfmanalysis = RFMAnalysis(data, 'customer_id', 'order_date', 'revenue')
rfmvisualizer = RFMVisualizer()

# %%
rfmanalysis.process_data()
rfmvisualizer.visualize_data(rfmanalysis.rfm_data)
